# %%
import pandas as pd
import glob
import re
import numpy

# %%
countries = ['australia', 'austria', 'belgium', 'brazil', 'canada', 'chile', 'china', 'czechia', 'denmark', 'estonia', 'finland', 'france', 'germany', 'greece', 'hungary', 'iceland', 'india', 'ireland', 'israel', 'italy', 'japan', 'korea', 'latvia', 'lithuania', 'luxembourg', 'mexico', 'netherlands', 'new zealand', 'norway', 'poland', 'portugal', 'slovakia', 'slovenia', 'spain', 'sweden', 'switzerland', 'turkey', 'united kingdom', 'usa', 'rep. of korea']
breiger_commodity = [0, 2, 3, 6]
#oecd_countries = ['austria', 'belgium', 'canada', 'denmark', 'france', 'germany', 'greece', 'iceland', 'ireland', 'luxembourg','netherlands', 'norway', 'portugal', 'spain', 'sweden', 'switzerland', 'turkey', 'united kingdom', 'usa', 'italy', 'japan', 'finland', 'australia', 'israel']

# %%
# Combine all files
path = r'C:\Users\Dhruval\Documents\MACSS\2019_Autumn\Network Analysis\NetworkAnalysis_Project\Raw Data 2008' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

data = pd.concat(li, axis=0, ignore_index=True)
# Out:
# C:\Users\Dhruval\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()

# %%
#Drop Columns
data.drop(columns=['Classification', 'Period', 'Period Desc.', 'Aggregate Level',
       'Is Leaf Code','Reporter Code', 'Reporter ISO', 'Partner Code', 'Partner ISO',
       '2nd Partner Code', '2nd Partner', '2nd Partner ISO',
       'Customs Proc. Code', 'Customs', 'Mode of Transport Code', 'Trade Flow Code', 
       'Mode of Transport', 'Qty Unit Code',
       'Qty Unit', 'Qty', 'Alt Qty Unit Code', 'Alt Qty Unit', 'Alt Qty',
       'Netweight (kg)', 'Gross weight (kg)', 'CIF Trade Value (US$)', 'FOB Trade Value (US$)', 'Flag'], inplace=True)

# %%
#lower the strings
data['Reporter'] = data['Reporter'].str.lower()
data['Partner'] = data['Partner'].str.lower()
data['Trade Flow'] = data['Trade Flow'].str.lower()

#Remove all re-imports
data = data.drop(data[data['Trade Flow'] == 're-import'].index)

#Remove countries that are not in the list
data = data[data['Partner'].isin(countries)]
#Remove countries that are not in the list
data = data[data['Reporter'].isin(countries)]

# %%
data_matrix = data.groupby(['Reporter', 'Partner'],as_index = False)['Trade Value (US$)'].sum().pivot('Reporter', 'Partner').fillna(0)
data_matrix.columns = data_matrix.columns.droplevel(0)
del data_matrix.index.name

data_matrix.head()
# Out:
# Partner       australia       austria       belgium        brazil  \
# australia  3.836946e+08  2.118033e+08  1.453485e+09  1.605250e+09
# austria    2.451348e+08  0.000000e+00  1.538599e+09  6.028196e+08
# belgium    1.634344e+09  2.225965e+09  0.000000e+00  3.914456e+09
# brazil     1.527751e+09  4.293379e+08  3.628935e+09  8.161059e+07
# canada     1.403100e+09  2.870197e+08  3.538944e+09  2.903548e+09
#
# Partner          canada         chile         china       czechia  \
# australia  1.101525e+09  7.544952e+08  2.930595e+10  1.357930e+08
# austria    4.459359e+08  8.236241e+07  1.364775e+09  5.341192e+09
# belgium    2.887683e+09  3.315177e+08  8.480619e+09  1.930058e+09
# brazil     2.530107e+09  5.948119e+09  1.865117e+10  1.105610e+08
# canada     4.717802e+08  1.746267e+09  1.375860e+10  1.621146e+08
#
# Partner         denmark      estonia  ...      portugal  rep. of korea  \
# australia  3.579910e+08    9877886.0  ...  5.776082e+07   1.478061e+10
# austria    5.464473e+08   51935156.0  ...  3.297839e+08   3.275576e+08
# belgium    1.593961e+09  173570529.0  ...  1.315396e+09   1.451376e+09
# brazil     2.688170e+08   26043327.0  ...  1.706954e+09   3.498394e+09
# canada     4.815123e+08   25247076.0  ...  3.607759e+08   3.789523e+09
#
# Partner        slovakia      slovenia         spain        sweden  \
# australia  1.284272e+07  1.994603e+07  8.184326e+08  7.742065e+08
# austria    3.422955e+09  2.377380e+09  1.486341e+09  1.312950e+09
# belgium    5.861511e+08  2.610716e+08  6.786880e+09  4.068156e+09
# brazil     1.839432e+07  2.606416e+08  4.000093e+09  7.019484e+08
# canada     4.891963e+07  4.044713e+07  1.337545e+09  6.268869e+08
#
# Partner     switzerland        turkey  united kingdom           usa
# australia  2.536480e+08  8.232924e+08    2.353293e+09  6.848714e+09
# austria    4.141802e+09  8.402376e+08    1.873528e+09  1.837024e+09
# belgium    3.937843e+09  2.441762e+09    2.202006e+10  9.977590e+09
# brazil     1.104137e+09  6.855587e+08    2.779184e+09  2.179694e+10
# canada     3.326749e+08  1.374410e+09    9.697153e+09  2.641859e+11
#
# [5 rows x 39 columns]

# %%
#Save full dataset to file
data_matrix.to_csv(r'C:\Users\Dhruval\Documents\MACSS\2019_Autumn\Network Analysis\NetworkAnalysis_Project\Raw Data 2008\matrix\all_data_matrix_2008.csv', index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-ea736f6aa79c> in <module>()
#       1 #Save full dataset to file
# ----> 2 data_matrix.to_csv(r'C:\Users\Dhruval\Documents\MACSS\2019_Autumn\Network Analysis\NetworkAnalysis_Project\Raw Data 2008\matrix\all_data_matrix_2008.csv', index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Dhruval\\Documents\\MACSS\\2019_Autumn\\Network Analysis\\NetworkAnalysis_Project\\Raw Data 2008\\matrix\\all_data_matrix_2008.csv'

# %%
agr_data = data[data['Commodity Code'] == 0]
agr_matrix = agr_data.groupby(['Reporter', 'Partner'],as_index = False)['Trade Value (US$)'].sum().pivot('Reporter', 'Partner').fillna(0)
agr_matrix.columns = agr_matrix.columns.droplevel(0)
del agr_matrix.index.name

#Save full dataset to file
agr_matrix.to_csv(r'C:\Users\Dhruval\Documents\MACSS\2019_Autumn\Network Analysis\NetworkAnalysis_Project\Raw Data 2008\matrix\all_2008_agr_m.csv', index=True)

# %%
raw_data = data[data['Commodity Code'] == 2]
raw_matrix = raw_data.groupby(['Reporter', 'Partner'],as_index = False)['Trade Value (US$)'].sum().pivot('Reporter', 'Partner').fillna(0)
raw_matrix.columns = raw_matrix.columns.droplevel(0)
del raw_matrix.index.name

#Save full dataset to file
raw_matrix.to_csv(r'C:\Users\Dhruval\Documents\MACSS\2019_Autumn\Network Analysis\NetworkAnalysis_Project\Raw Data 2008\matrix\all_2008_raw_m.csv', index=True)

# %%
man_data = data[data['Commodity Code'] == 6]
man_matrix = man_data.groupby(['Reporter', 'Partner'],as_index = False)['Trade Value (US$)'].sum().pivot('Reporter', 'Partner').fillna(0)
man_matrix.columns = man_matrix.columns.droplevel(0)
del man_matrix.index.name

#Save full dataset to file
man_matrix.to_csv(r'C:\Users\Dhruval\Documents\MACSS\2019_Autumn\Network Analysis\NetworkAnalysis_Project\Raw Data 2008\matrix\all_2008_man_m.csv', index=True)

# %%
enr_data = data[data['Commodity Code'] == 3]
enr_matrix = enr_data.groupby(['Reporter', 'Partner'],as_index = False)['Trade Value (US$)'].sum().pivot('Reporter', 'Partner').fillna(0)
enr_matrix.columns = enr_matrix.columns.droplevel(0)
del enr_matrix.index.name

#Save full dataset to file
enr_matrix.to_csv(r'C:\Users\Dhruval\Documents\MACSS\2019_Autumn\Network Analysis\NetworkAnalysis_Project\Raw Data 2008\matrix\all_2008_enr_m.csv', index=True)
